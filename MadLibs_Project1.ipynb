# %%
#Steps to Run in Google Colab:
#1. Install dependencies:
# !pip install streamlit pyngrok

# %% [markdown]
# ## Code Part

# %%
## take input from user and pass it to function which posses story with help of f strin
def mad_lib():
  print("Welcome to Mad Lib! Provide this Below information")
  noun = str(input("Enter a Noun: "))
  verb = str((input("Enter a Verb: ")))
  adjective= str(input("Enter Adjective: "))
  place = str(input("Enter a place: "))
  print("HERE IS YOU STORY \n")
  return f"One day {noun} was running very {verb} in {place}"

mad_lib()
# Out:
# Welcome to Mad Lib! Provide this Below information
# Enter a Noun: afnan
# Enter a Verb: ksk
# Enter Adjective: adsd
# Enter a place: dfa
# HERE IS YOU STORY
# 'One day afnan was running very ksk in dfa'

# %%
## this will ask for password where you will use ip address from external url from after  // till before :
# !streamlit run app.py & npx localtunnel --port 8501
