# %%
import random

# %%
## Number of password and password lenght from user
def Passwrod_Generator():
  print("Welcome to Password Generator! ")
  number_PWD = int(input("How many pasword do you want?: "))
  lenght = int(input("Required Length of each password."))
  char = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz1234567890!@#$%^&*()'
  print("Generaeting Your Password: ")
  for pwd in range(number_PWD):
    password = ''

    for c in range(lenght):
      choice=random.choice(char)
      password+=choice
    print(password)
    #return password

# %%
Passwrod_Generator()
# Out:
# Welcome to Password Generator!
# How many pasword do you want?: 5
# Required Length of each password.5
# Generaeting Your Password:
# j&qA8
# lESkr
# $UC1h
# lbmYk
# Oe4#F

# %%
5
# Out:
# 0vAg9
